# %% [markdown]
# ## Haar Cascade Sample

# %% [markdown]
# - **image**: Image that will be processed (frame).
# - **scaleFactor**: Image reduction in order to find the object at different scales (Similar to a simplification).
# - **minNeighbors**: How many near coincidences are needed in order to classify as the object.
# - **minSize**: Minimum required sizes of the object in the image.

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

print(cv2.data.haarcascades)
# Out:
# c:\Users\david\test-venv\Lib\site-packages\cv2\data\

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)

print(cv2.data.haarcascades)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)


    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for face in faces:
        x, y, w, h = face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    cv2.imshow('Face Detection', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\david\test-venv\Lib\site-packages\cv2\data\
# 357.0
# 359.5
# 359.5
# 358.0
# 359.0
# 357.5
# 359.5
# 358.5
# 358.0
# 359.0
# 357.0
# 358.0
# 359.5
# 358.5
# 359.0
# 358.0
# 358.5
# 355.5
# 354.5
# 352.5
# 352.0
# 349.5
# 347.0
# 334.5
# 346.5
# 345.0
# 343.0
# 343.0
# 343.0
# 338.0
# 327.5
# 337.0
# 605.0
# 336.0
# 324.0
# 597.0
# 332.0
# 322.5
# 588.5
# 333.0
# 321.5
# 579.5
# 333.0
# 322.0
# 571.5
# 329.5
# 319.0
# 564.5
# 329.0
# 317.0
# 557.5
# 327.5
# 316.0
# 552.0
# 324.0
# 314.5
# 548.5
# 322.0
# 313.5
# 545.5
# 317.5
# 542.5
# 315.0
# 539.5
# 314.0
# 537.5
# 314.0
# 535.0
# 310.5
# 534.0
# 308.5
# 533.0
# 307.5
# 533.0
# 307.0
# 535.0
# 306.5
# 536.0
# 306.5
# 538.0
# 305.0
# 540.5
# 307.0
# 542.0
# 306.5
# 543.0
# 307.5
# 543.0
# 309.0
# 543.5
# 309.0
# 544.0
# 309.0
# 544.5
# 311.0
# 545.0
# 310.5
# 545.0
# 311.0
# 546.0
# 310.5
# 546.5
# 311.0
# 546.0
# 309.5
# 307.5
# 545.5
# 313.5
# 304.5
# 545.5
# 313.0
# 306.0
# 544.5
# 312.5
# 304.5
# 544.5
# 312.0
# 543.5
# ...

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for face in faces:
        x, y, w, h = face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    cv2.imshow('Face Detection', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Haar Cascade for bigger face detection

# %%
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

    x_ = 0
    y_ = 0
    w_ = 0
    h_ = 0
    area = 0
    for (x, y, w, h) in faces:
        if (w * h) > area:
            x_ = x
            y_ = y
            w_ = w
            h_ = h
            area = w * h

    if area > 0:
        cv2.rectangle(frame, (x_, y_), (x_+w_, y_+h_), (255, 0, 0), 2)

    cv2.imshow('Face Detection', frame)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Haar Cascade for bigger face (Simplified)

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(faces) > 0:
        largest_face = max(faces, key=lambda face: face[2] * face[3])
        x, y, w, h = largest_face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    cv2.imshow('Face Detection', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
